# %%
import os
import subprocess
os.chdir("..")
print(os.getcwd())  # 打印當前工作目錄的絕對路徑
# Out:
# d:\pythonProject\IC Lab\Gait_analysis\pyskl

# %%
from colab.tools import prinfo

# %%
# 🟢 主要訓練迴圈
feature = 'b'
for split in range(1, 2):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk_aug_multimetric_weight "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 30 --split {split} --cls 4 --model stgcn --lr 0.01 --loss CE --mt"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        
        # 使用 `prinfo()` 解析結果
        (
            train_cost, train_time, test_time, val_acc_4c, val_acc_3c, val_acc_2c, 
            test_acc_4c, test_acc_3c, test_acc_2c, f1, pre, rec, log
        ) = prinfo(b)

        # 輸出結果
        print(f"Run : {run:>3} | Train_cost : {train_cost:>8.3f}s | Train_time : {train_time:>8.3f}s | "
              f"Test_time : {test_time:>8.3f}s | Val_acc_4c : {val_acc_4c:>8.4f} | "
              f"Val_acc_3c : {val_acc_3c:>8.4f} | Val_acc_2c : {val_acc_2c:>8.4f} | "
              f"Test_acc_4c : {test_acc_4c:>8.4f} | Test_acc_3c : {test_acc_3c:>8.4f} | "
              f"Test_acc_2c : {test_acc_2c:>8.4f} | F1 : {f1:>8.4f} | "
              f"Precision : {pre:>8.4f} | Recall : {rec:>8.4f} | Log : {log}")
# Out:
# Split : 1/ Feature: b

# %%
# 🟢 主要訓練迴圈
print(f'lstm')
feature = 'j'
for split in range(1, 6):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk_aug_multimetric_weight "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 30 --split {split} --cls 4 --model lstm --lr 0.01 --loss CE"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        
        # 使用 `prinfo()` 解析結果
        (
            train_cost, train_time, test_time, val_acc_4c, val_acc_3c, val_acc_2c, 
            test_acc_4c, test_acc_3c, test_acc_2c, f1, pre, rec, log
        ) = prinfo(b)

        # 輸出結果
        print(f"Run : {run:>3} | Train_cost : {train_cost:>8.3f}s | Train_time : {train_time:>8.3f}s | "
              f"Test_time : {test_time:>8.3f}s | Val_acc_4c : {val_acc_4c:>8.4f} | "
              f"Val_acc_3c : {val_acc_3c:>8.4f} | Val_acc_2c : {val_acc_2c:>8.4f} | "
              f"Test_acc_4c : {test_acc_4c:>8.4f} | Test_acc_3c : {test_acc_3c:>8.4f} | "
              f"Test_acc_2c : {test_acc_2c:>8.4f} | F1 : {f1:>8.4f} | "
              f"Precision : {pre:>8.4f} | Recall : {rec:>8.4f} | Log : {log}")
# Out:
# lstm
# Split : 1/ Feature: j
# Run :   0 | Train_cost :   49.778s | Train_time :   32.990s | Test_time :    0.081s | Val_acc_4c :   0.4086 | Val_acc_3c :   0.4891 | Val_acc_2c :   0.5625 | Test_acc_4c :   0.4214 | Test_acc_3c :   0.5000 | Test_acc_2c :   0.5744 | F1 :   0.5224 | Precision :   0.5951 | Recall :   0.4655 | Log : results/record_20250318_154616_drunk_j_split1_4C-0.4214_3C-0.5000_2C-0.5744_2CP-0.5951_2CR-0.4655_2CF-0.5224.txt
# Run :   1 | Train_cost :   53.164s | Train_time :   36.300s | Test_time :    0.067s | Val_acc_4c :   0.4086 | Val_acc_3c :   0.4891 | Val_acc_2c :   0.5625 | Test_acc_4c :   0.4214 | Test_acc_3c :   0.5000 | Test_acc_2c :   0.5744 | F1 :   0.5224 | Precision :   0.5951 | Recall :   0.4655 | Log : results/record_20250318_154717_drunk_j_split1_4C-0.4214_3C-0.5000_2C-0.5744_2CP-0.5951_2CR-0.4655_2CF-0.5224.txt
# ...

# %%
# # 🟢 主要訓練迴圈 # 可以參考
# feature = 'b'
# for split in range(1, 6):
#     print(f'Split : {split}/ Feature: {feature}')
#     for run in range(5):
#         command = (
#             f"python -m colab.training_tools.kaggle_train_drunk_aug_multimetric_weight "
#             f"--batch 128 --data drunk --feature {feature} "
#             f"--epochs 30 --split {split} --cls 4 --model stgcn --lr 0.01 --loss CE --mt"
#         )
#         # 使用 `!` 運行 Shell 命令
#         b = !{command}
#         # print(b)
        
#         # 使用 `prinfo()` 解析結果
#         (
#             train_cost, train_time, test_time, val_acc_4c, val_acc_3c, val_acc_2c, 
#             test_acc_4c, test_acc_3c, test_acc_2c, f1, pre, rec, log
#         ) = prinfo(b)

#         # 輸出結果
#         print(f"Run : {run:>3} | Train_cost : {train_cost:>8.3f}s | Train_time : {train_time:>8.3f}s | "
#               f"Test_time : {test_time:>8.3f}s | Val_acc_4c : {val_acc_4c:>8.4f} | "
#               f"Val_acc_3c : {val_acc_3c:>8.4f} | Val_acc_2c : {val_acc_2c:>8.4f} | "
#               f"Test_acc_4c : {test_acc_4c:>8.4f} | Test_acc_3c : {test_acc_3c:>8.4f} | "
#               f"Test_acc_2c : {test_acc_2c:>8.4f} | F1 : {f1:>8.4f} | "
#               f"Precision : {pre:>8.4f} | Recall : {rec:>8.4f} | Log : {log}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Train_cost :  371.138s | Train_time :  340.129s | Test_time :   14.020s | Val_acc_4c :   0.4975 | Val_acc_3c :   0.5689 | Val_acc_2c :   0.7206 | Test_acc_4c :   0.4918 | Test_acc_3c :   0.5480 | Test_acc_2c :   0.7480 | F1 :   0.7698 | Precision :   0.6325 | Recall :   0.9833 | Log : results/record_20250316_203202_drunk_b_split1_4C-0.4918_3C-0.5480_2C-0.7480_2CP-0.6325_2CR-0.9833_2CF-0.7698.txt
# Run :   1 | Train_cost :  414.510s | Train_time :  349.738s | Test_time :   47.605s | Val_acc_4c :   0.5414 | Val_acc_3c :   0.6053 | Val_acc_2c :   0.7782 | Test_acc_4c :   0.6051 | Test_acc_3c :   0.6724 | Test_acc_2c :   0.8612 | F1 :   0.8571 | Precision :   0.7669 | Recall :   0.9714 | Log : results/record_20250316_203905_drunk_b_split1_4C-0.6051_3C-0.6724_2C-0.8612_2CP-0.7669_2CR-0.9714_2CF-0.8571.txt
# ...

# %%
# feature = 'b'
# for split in [1, 2, 3, 4, 5]:
#     print(f'Split : {split}/ Feature: {feature}')
#     for run in range(5):
#         command = (
#             f"python -m colab.training_tools.kaggle_train_testuse "
#             f"--batch 128 --data drunk --feature {feature} "
#             f"--epochs 80 --split {split} --cls 3 --model stgcn --lr 0.1"
#         )
#         # 使用 `!` 運行 Shell 命令
#         b = !{command}
#         # print(b)
#         val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
#         print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       94.270831 | Test_acc :       87.916666 | F1 :        0.879167 | F18 :        0.879167 | Training_time :      473.269578
# Run :   1 | Val_acc :       92.447919 | Test_acc :       90.416664 | F1 :        0.904167 | F18 :        0.904167 | Training_time :      463.115660
# Run :   2 | Val_acc :       93.750000 | Test_acc :       88.333333 | F1 :        0.883333 | F18 :        0.883333 | Training_time :      459.037295
# Run :   3 | Val_acc :       94.270831 | Test_acc :       91.250002 | F1 :        0.912500 | F18 :        0.912500 | Training_time :      454.178359
# Run :   4 | Val_acc :       93.229169 | Test_acc :       88.125002 | F1 :        0.881250 | F18 :        0.881250 | Training_time :      449.881736
# Split : 2/ Feature: b
# Run :   0 | Val_acc :       95.833331 | Test_acc :       87.291664 | F1 :        0.872917 | F18 :        0.872917 | Training_time :      446.787537
# ...

# %%
# feature = 'b'
# for split in [1, 2, 3, 4, 5]:
#     print(f'Split : {split}/ Feature: {feature}')
#     for run in range(5):
#         command = (
#             f"python -m colab.training_tools.kaggle_train_testuse "
#             f"--batch 128 --data drunk --feature {feature} "
#             f"--epochs 80 --split {split} --cls 3 --model stgcn --lr 0.1 --mt"
#         )
#         # 使用 `!` 運行 Shell 命令
#         b = !{command}
#         # print(b)
#         val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
#         print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       93.489581 | Test_acc :       91.458333 | F1 :        0.914583 | F18 :        0.914583 | Training_time :      448.055154
# Run :   1 | Val_acc :       93.229169 | Test_acc :       86.250001 | F1 :        0.862500 | F18 :        0.862500 | Training_time :      448.752330
# Run :   2 | Val_acc :       92.447919 | Test_acc :       87.083334 | F1 :        0.870833 | F18 :        0.870833 | Training_time :      446.902777
# Run :   3 | Val_acc :       93.750000 | Test_acc :       89.999998 | F1 :        0.900000 | F18 :        0.900000 | Training_time :      448.349684
# Run :   4 | Val_acc :       91.666669 | Test_acc :       91.041666 | F1 :        0.910417 | F18 :        0.910417 | Training_time :      447.188116
# Split : 2/ Feature: b
# Run :   0 | Val_acc :       92.968750 | Test_acc :       86.250001 | F1 :        0.862500 | F18 :        0.862500 | Training_time :      448.036065
# ...

# %%
# PD
feature = 'j'
for split in [1, 3]:
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(1):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 64 --data pd --feature {feature} "
            f"--epochs 30 --split {split} --cls 3 --model stgcn --lr 0.1"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: j
# Run :   0 | Val_acc :       75.862068 | Test_acc :       73.416841 | F1 :        0.734168 | F18 :        0.734168 | Training_time :      959.057443
# Split : 3/ Feature: j
# Run :   0 | Val_acc :       79.623824 | Test_acc :       76.200420 | F1 :        0.762004 | F18 :        0.762004 | Training_time :      908.781284

# %%
# PD
feature = 'j'
for split in [1, 3]:
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(1):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 64 --data pd --feature {feature} "
            f"--epochs 30 --split {split} --cls 3 --model stgcn --lr 0.1 --mt"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: j
# Run :   0 | Val_acc :       87.042844 | Test_acc :       84.551150 | F1 :        0.845511 | F18 :        0.845511 | Training_time :      922.470551
# Split : 3/ Feature: j
# Run :   0 | Val_acc :       83.385581 | Test_acc :       79.192764 | F1 :        0.791928 | F18 :        0.791928 | Training_time :     1005.815374

# %%
# MMGS Openpose
feature = 'j'
for split in range(1, 3):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 64 --data mmgs --feature {feature} "
            f"--epochs 80 --split {split} --cls 3 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       62.761503 | Test_acc :       61.445785 | F1 :        0.614458 | F18 :        0.614458 | Training_time :      217.923337
# Run :   1 | Val_acc :       61.506277 | Test_acc :       59.939760 | F1 :        0.599398 | F18 :        0.599398 | Training_time :      228.946517
# Run :   2 | Val_acc :       65.690374 | Test_acc :       59.337348 | F1 :        0.593373 | F18 :        0.593374 | Training_time :      232.591466

# %%
# MMGS
feature = 'b'
for split in range(1, 3):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 64 --data mmgs --feature {feature} "
            f"--epochs 80 --split {split} --cls 3 --model stgcn --mt"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")

# %%
# aug RAW
feature = 'b'
for split in range(1, 6):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 30 --split {split} --cls 3 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       91.666669 | Test_acc :       86.250001 | F1 :        0.862500 | F18 :        0.862500 | Training_time :      169.866350
# Run :   1 | Val_acc :       94.010419 | Test_acc :       87.291664 | F1 :        0.872917 | F18 :        0.872917 | Training_time :      189.726065
# Run :   2 | Val_acc :       91.927081 | Test_acc :       89.166665 | F1 :        0.891667 | F18 :        0.891667 | Training_time :      199.314708
# Run :   3 | Val_acc :       94.010419 | Test_acc :       87.916666 | F1 :        0.879167 | F18 :        0.879167 | Training_time :      213.786440
# Run :   4 | Val_acc :       92.447919 | Test_acc :       89.999998 | F1 :        0.900000 | F18 :        0.900000 | Training_time :      234.296938
# Split : 2/ Feature: b

# %%
# Aug MT
feature = 'b'
for split in range(1, 6):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 30 --split {split} --cls 3 --model stgcn --mt"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       92.447919 | Test_acc :       87.916666 | F1 :        0.879167 | F18 :        0.879167 | Training_time :      246.192962
# Run :   1 | Val_acc :       94.010419 | Test_acc :       91.250002 | F1 :        0.912500 | F18 :        0.912500 | Training_time :      236.387045
# Run :   2 | Val_acc :       92.447919 | Test_acc :       88.333333 | F1 :        0.883333 | F18 :        0.883333 | Training_time :      244.874920
# Run :   3 | Val_acc :       94.010419 | Test_acc :       88.333333 | F1 :        0.883333 | F18 :        0.883333 | Training_time :      229.834918
# Run :   4 | Val_acc :       90.625000 | Test_acc :       88.541669 | F1 :        0.885417 | F18 :        0.885417 | Training_time :      208.402668
# Split : 2/ Feature: b
# Run :   0 | Val_acc :       92.708331 | Test_acc :       87.916666 | F1 :        0.879167 | F18 :        0.879167 | Training_time :      215.051830
# ...

# %%
# ORI RAW
feature = 'b'
for split in range(1, 6):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 64 --data drunk --feature {feature} "
            f"--epochs 30 --split {split} --cls 3 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       91.796875 | Test_acc :       82.187498 | F1 :        0.821875 | F18 :        0.821875 | Training_time :      244.593478
# Run :   1 | Val_acc :       91.015625 | Test_acc :       80.312502 | F1 :        0.803125 | F18 :        0.803125 | Training_time :      228.532389
# Run :   2 | Val_acc :       91.796875 | Test_acc :       84.687501 | F1 :        0.846875 | F18 :        0.846875 | Training_time :      223.810996
# Run :   3 | Val_acc :       89.062500 | Test_acc :       83.749998 | F1 :        0.837500 | F18 :        0.837500 | Training_time :      221.359666
# Run :   4 | Val_acc :       89.062500 | Test_acc :       84.062499 | F1 :        0.840625 | F18 :        0.840625 | Training_time :      220.545624
# Split : 2/ Feature: b
# Run :   0 | Val_acc :       92.578125 | Test_acc :       81.875002 | F1 :        0.818750 | F18 :        0.818750 | Training_time :      220.931303
# ...

# %%
# ORI MT
feature = 'b'
for split in range(1, 6):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 64 --data drunk --feature {feature} "
            f"--epochs 30 --split {split} --cls 3 --model stgcn --mt"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       91.015625 | Test_acc :       89.062500 | F1 :        0.890625 | F18 :        0.890625 | Training_time :      222.696954
# Run :   1 | Val_acc :       90.234375 | Test_acc :       86.562502 | F1 :        0.865625 | F18 :        0.865625 | Training_time :      223.517251
# Run :   2 | Val_acc :       88.281250 | Test_acc :       86.250001 | F1 :        0.862500 | F18 :        0.862500 | Training_time :      222.344716
# Run :   3 | Val_acc :       91.015625 | Test_acc :       85.937500 | F1 :        0.859375 | F18 :        0.859375 | Training_time :      221.924292
# Run :   4 | Val_acc :       87.500000 | Test_acc :       87.187499 | F1 :        0.871875 | F18 :        0.871875 | Training_time :      220.887505
# Split : 2/ Feature: b
# Run :   0 | Val_acc :       91.796875 | Test_acc :       82.187498 | F1 :        0.821875 | F18 :        0.821875 | Training_time :      220.885893
# ...

# %%
# ORI MT
feature = 'b'
for split in range(1, 6):
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 64 --data drunk --feature {feature} "
            f"--epochs 80 --split {split} --cls 3 --model stgcn --mt"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b
# Run :   0 | Val_acc :       91.406250 | Test_acc :       87.812501 | F1 :        0.878125 | F18 :        0.878125 | Training_time :      521.882358
# Run :   1 | Val_acc :       89.062500 | Test_acc :       86.874998 | F1 :        0.868750 | F18 :        0.868750 | Training_time :      607.815951
# Run :   2 | Val_acc :       90.625000 | Test_acc :       86.874998 | F1 :        0.868750 | F18 :        0.868750 | Training_time :      598.691300

# %%
split = 1
feature = 'j'
for split in [1, 2, 3]:
    print(f'DATA: MMGS/ Split : {split}/ Feature: {feature}/')
    for run in range(1):
        command = (
            f"python -m colab.training_tools.kaggle_train_testuse "
            f"--batch 128 --data mmgs --feature {feature} "
            f"--epochs 80 --split {split} --cls 3 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# DATA: MMGS/ Split : 1/ Feature: j/

# %%
split = 1
feature = 'b'
for lam in [0, 0.25, 0.5, 0.75]:
    print(f'Split : {split}/ Feature: {feature}/ Triplet loss ratio : {lam}')
    for run in range(5):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 80 --split {split} --cls 3 --model stgcn --lambda_val {lam}"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        # print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b/ Triplet loss ratio : 0
# Run :   0 | Val_acc :       89.583337 | Test_acc :       85.069442 | F1 :        0.853476 | F18 :        0.857257 | Training_time :      459.840702
# Run :   1 | Val_acc :       91.927087 | Test_acc :       82.083333 | F1 :        0.828112 | F18 :        0.842988 | Training_time :      504.796164
# Run :   2 | Val_acc :       88.281250 | Test_acc :       83.263886 | F1 :        0.842356 | F18 :        0.866142 | Training_time :      528.243457
# Run :   3 | Val_acc :       89.583325 | Test_acc :       84.305549 | F1 :        0.848006 | F18 :        0.856790 | Training_time :      521.088399
# Run :   4 | Val_acc :       86.197913 | Test_acc :       82.708335 | F1 :        0.836160 | F18 :        0.856075 | Training_time :      541.496126
# Split : 1/ Feature: b/ Triplet loss ratio : 0.25
# Run :   0 | Val_acc :       86.284721 | Test_acc :       83.402777 | F1 :        0.844676 | F18 :        0.868295 | Training_time :      509.751683

# %%
split = 1
feature = 'b'
lam = 0.5
for lr in [0.1, 0.05, 0.01, 0.005, 0.001]:
    print(f'Split : {split}/ Feature: {feature}/ Triplet loss ratio : {lam}/ lr: {lr}')
    for run in range(1):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 80 --split {split} --cls 3 --model stgcn --lambda_val {lam} --lr {lr}"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        print(b)
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: b/ Triplet loss ratio : 0.5/ lr: 0.1
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
split = 1
for feature in ['j', 'b', 'jm', 'bm']:
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(30):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 80 --split {split} --cls 4 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")
# Out:
# Split : 1/ Feature: j
# Run :   0 | Val_acc :       75.781250 | Test_acc :       69.270831 | F1 :        0.688980 | F18 :        0.687286 | Training_time :      517.617156
# Run :   1 | Val_acc :       78.125000 | Test_acc :       66.562498 | F1 :        0.661723 | F18 :        0.659848 | Training_time :      510.399536
# Run :   2 | Val_acc :       76.171875 | Test_acc :       62.708330 | F1 :        0.618703 | F18 :        0.616015 | Training_time :      500.253438
# Run :   3 | Val_acc :       77.213544 | Test_acc :       64.375001 | F1 :        0.640588 | F18 :        0.639781 | Training_time :      505.012802
# Run :   4 | Val_acc :       73.437500 | Test_acc :       66.250002 | F1 :        0.661094 | F18 :        0.664272 | Training_time :      524.675525
# Run :   5 | Val_acc :       77.473956 | Test_acc :       65.937501 | F1 :        0.658385 | F18 :        0.660970 | Training_time :      496.166102
# ...

# %%
split = 2
for feature in ['j', 'b', 'jm', 'bm']:
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(30):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 80 --split {split} --cls 4 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")

# %%
split = 3
for feature in ['j', 'b', 'jm', 'bm']:
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(30):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 80 --split {split} --cls 4 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")

# %%
split = 4
for feature in ['j', 'b', 'jm', 'bm']:
    print(f'Split : {split}/ Feature: {feature}')
    for run in range(30):
        command = (
            f"python -m colab.training_tools.kaggle_train_drunk "
            f"--batch 128 --data drunk --feature {feature} "
            f"--epochs 80 --split {split} --cls 4 --model stgcn"
        )
        # 使用 `!` 運行 Shell 命令
        b = !{command}
        val_acc, test_acc,  train_time, f1, f18 = prinfo(b)
        print(f"Run : {run:>3} | Val_acc : {val_acc:>15.6f} | Test_acc : {test_acc:>15.6f} | F1 : {f1:>15.6f} | F18 : {f18:>15.6f} | Training_time : {train_time:>15.6f}")

# %%
# 修正數據解析邏輯
data = """
Split : 1/ Feature: b
Run :   0 | Train_cost :  371.138s | Train_time :  340.129s | Test_time :   14.020s | Val_acc_4c :   0.4975 | Val_acc_3c :   0.5689 | Val_acc_2c :   0.7206 | Test_acc_4c :   0.4918 | Test_acc_3c :   0.5480 | Test_acc_2c :   0.7480 | F1 :   0.7698 | Precision :   0.6325 | Recall :   0.9833 | Log : results/record_20250316_203202_drunk_b_split1_4C-0.4918_3C-0.5480_2C-0.7480_2CP-0.6325_2CR-0.9833_2CF-0.7698.txt
Run :   1 | Train_cost :  414.510s | Train_time :  349.738s | Test_time :   47.605s | Val_acc_4c :   0.5414 | Val_acc_3c :   0.6053 | Val_acc_2c :   0.7782 | Test_acc_4c :   0.6051 | Test_acc_3c :   0.6724 | Test_acc_2c :   0.8612 | F1 :   0.8571 | Precision :   0.7669 | Recall :   0.9714 | Log : results/record_20250316_203905_drunk_b_split1_4C-0.6051_3C-0.6724_2C-0.8612_2CP-0.7669_2CR-0.9714_2CF-0.8571.txt
Run :   2 | Train_cost :  376.019s | Train_time :  344.823s | Test_time :   14.305s | Val_acc_4c :   0.3997 | Val_acc_3c :   0.4524 | Val_acc_2c :   0.6391 | Test_acc_4c :   0.5071 | Test_acc_3c :   0.5388 | Test_acc_2c :   0.7776 | F1 :   0.7854 | Precision :   0.6695 | Recall :   0.9500 | Log : results/record_20250316_204529_drunk_b_split1_4C-0.5071_3C-0.5388_2C-0.7776_2CP-0.6695_2CR-0.9500_2CF-0.7854.txt
Run :   3 | Train_cost :  394.803s | Train_time :  361.724s | Test_time :   15.341s | Val_acc_4c :   0.5501 | Val_acc_3c :   0.6203 | Val_acc_2c :   0.7719 | Test_acc_4c :   0.5031 | Test_acc_3c :   0.5571 | Test_acc_2c :   0.7551 | F1 :   0.7749 | Precision :   0.6393 | Recall :   0.9833 | Log : results/record_20250316_205212_drunk_b_split1_4C-0.5031_3C-0.5571_2C-0.7551_2CP-0.6393_2CR-0.9833_2CF-0.7749.txt
Run :   3 | Train_cost :  372.618s | Train_time :  342.453s | Test_time :   13.630s | Val_acc_4c :   0.8380 | Val_acc_3c :   0.9605 | Val_acc_2c :   1.0000 | Test_acc_4c :   0.7905 | Test_acc_3c :   0.8810 | Test_acc_2c :   0.9867 | F1 :   0.9843 | Precision :   0.9932 | Recall :   0.9756 | Log : results/record_20250316_230624_drunk_b_split5_4C-0.7905_3C-0.8810_2C-0.9867_2CP-0.9932_2CR-0.9756_2CF-0.9843.txt
Run :   4 | Train_cost :  373.132s | Train_time :  342.271s | Test_time :   13.804s | Val_acc_4c :   0.8278 | Val_acc_3c :   0.9592 | Val_acc_2c :   1.0000 | Test_acc_4c :   0.7848 | Test_acc_3c :   0.8800 | Test_acc_2c :   0.9819 | F1 :   0.9787 | Precision :   0.9865 | Recall :   0.9711 | Log : results/record_20250316_231245_drunk_b_split5_4C-0.7848_3C-0.8800_2C-0.9819_2CP-0.9865_2CR-0.9711_2CF-0.9787.txt
"""

# 解析數據
parsed_data = []
current_split = None

for line in data.split("\n"):
    line = line.strip()
    if line.startswith("Split"):
        current_split = int(line.split(":")[1].split("/")[0].strip())
    elif line.startswith("Run"):
        parts = line.split("|")
        run = int(parts[0].split(":")[1].strip())

        # 只提取準確率數據
        val_acc_4c = float(parts[4].split(":")[1].strip())
        val_acc_3c = float(parts[5].split(":")[1].strip())
        val_acc_2c = float(parts[6].split(":")[1].strip())
        test_acc_4c = float(parts[7].split(":")[1].strip())
        test_acc_3c = float(parts[8].split(":")[1].strip())
        test_acc_2c = float(parts[9].split(":")[1].strip())

        parsed_data.append([current_split, run, val_acc_4c, val_acc_3c, val_acc_2c, test_acc_4c, test_acc_3c, test_acc_2c])

# 轉換為 DataFrame
df = pd.DataFrame(parsed_data, columns=["Split", "Run", "Val_acc_4c", "Val_acc_3c", "Val_acc_2c", "Test_acc_4c", "Test_acc_3c", "Test_acc_2c"])

# 計算每個 Split 的相關性矩陣
split_correlation = {split: group[["Val_acc_4c", "Val_acc_3c", "Val_acc_2c", "Test_acc_4c", "Test_acc_3c", "Test_acc_2c"]].corr() for split, group in df.groupby("Split")}

# 顯示 Split 3, 4, 5 的相關性矩陣
for split in [1, 2, 3, 4, 5]:
    if split in split_correlation:
        # tools.display_dataframe_to_user(name=f"Split {split} Correlation Matrix", dataframe=split_correlation[split])
        print(split)
        print(split_correlation[split])
# Out:
# 1
#              Val_acc_4c  Val_acc_3c  Val_acc_2c  Test_acc_4c  Test_acc_3c  \
# Val_acc_4c     1.000000    0.999260    0.997670     0.023581     0.226452
# Val_acc_3c     0.999260    1.000000    0.994564    -0.006349     0.199877
# Val_acc_2c     0.997670    0.994564    1.000000     0.084064     0.281365
# Test_acc_4c    0.023581   -0.006349    0.084064     1.000000     0.972768
# Test_acc_3c    0.226452    0.199877    0.281365     0.972768     1.000000
# Test_acc_2c   -0.110823   -0.141563   -0.047882     0.986881     0.924877
#
#              Test_acc_2c
# Val_acc_4c     -0.110823
# Val_acc_3c     -0.141563
# Val_acc_2c     -0.047882
# Test_acc_4c     0.986881
# Test_acc_3c     0.924877
# Test_acc_2c     1.000000
# 2
#              Val_acc_4c  Val_acc_3c  Val_acc_2c  Test_acc_4c  Test_acc_3c  \
# Val_acc_4c     1.000000    0.991898    0.992451     0.963172     0.566840
# Val_acc_3c     0.991898    1.000000    0.972664     0.938568     0.610550
# ...
