# %%
# !pip install pipreqs
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (d:\pythonproject\ic lab\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\pythonproject\ic lab\venv\lib\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/798.3 kB ? eta -:--:--
#    - -------------------------------------- 30.7/798.3 kB 1.3 MB/s eta 0:00:01
#    --- ----------------------------------- 71.7/798.3 kB 975.2 kB/s eta 0:00:01
#    ------ --------------------------------- 122.9/798.3 kB 1.0 MB/s eta 0:00:01
#    ------- -------------------------------- 153.6/798.3 kB 1.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 204.8/798.3 kB 1.1 MB/s eta 0:00:01
# ...

# %%
# !pipreqs . --force
# Out:
# INFO: Not scanning for jupyter notebooks.
# WARNING: Import named "colab" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "colab" was resolved to "colab:1.13.5" package (https://pypi.org/project/colab/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "einops" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "einops" was resolved to "einops:0.8.1" package (https://pypi.org/project/einops/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "numpy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "numpy" was resolved to "numpy:2.3.1" package (https://pypi.org/project/numpy/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# ...
